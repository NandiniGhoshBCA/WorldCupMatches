# %%
import pandas as pd  # It is used to import the pandas library.
import numpy as np   # It is used to import the numpy library.
import seaborn as sns # It is used to import the seaborn library.
import matplotlib.pyplot as plt  # It is used to import the matplotlib library
dt=pd.read_csv("/content/WorldCupMatches.csv") # It is used to read the data from the csv file.
dt # It's print the data.
# Out:
#         Year              Datetime    Stage         Stadium         City  \
# 0     1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1     1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2     1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3     1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4     1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# ...      ...                   ...      ...             ...          ...
# 4567     NaN                   NaN      NaN             NaN          NaN
# 4568     NaN                   NaN      NaN             NaN          NaN
# 4569     NaN                   NaN      NaN             NaN          NaN
# 4570     NaN                   NaN      NaN             NaN          NaN
# 4571     NaN                   NaN      NaN             NaN          NaN
#
#      Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# ...

# %%
dt.head()  # It is used to print top 5 rows.
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
dt.tail() # It is used to print last 5 rows.
# Out:
#       Year Datetime Stage Stadium City Home Team Name  Home Team Goals  \
# 4567   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4568   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4569   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4570   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4571   NaN      NaN   NaN     NaN  NaN            NaN              NaN
#
#       Away Team Goals Away Team Name Win conditions  Attendance  \
# 4567              NaN            NaN            NaN         NaN
# 4568              NaN            NaN            NaN         NaN
# 4569              NaN            NaN            NaN         NaN
# 4570              NaN            NaN            NaN         NaN
# 4571              NaN            NaN            NaN         NaN
#
#       Half-time Home Goals  Half-time Away Goals Referee Assistant 1  \
# 4567                   NaN                   NaN     NaN         NaN
# ...

# %%
dt[60:71] # It is used to print the data from 60 to 70.
# Out:
#       Year              Datetime    Stage  \
# 60  1950.0  29 Jun 1950 - 15:00   Group 2
# 61  1950.0  29 Jun 1950 - 15:30   Group 3
# 62  1950.0  29 Jun 1950 - 15:00   Group 2
# 63  1950.0  01 Jul 1950 - 15:00   Group 1
# 64  1950.0  02 Jul 1950 - 15:00   Group 2
# 65  1950.0  02 Jul 1950 - 15:00   Group 3
# 66  1950.0  02 Jul 1950 - 15:00   Group 4
# 67  1950.0  02 Jul 1950 - 15:40   Group 1
# 68  1950.0  02 Jul 1950 - 15:00   Group 2
# 69  1950.0  09 Jul 1950 - 15:00   Group 6
# 70  1950.0  09 Jul 1950 - 15:00   Group 6
#
#                                       Stadium             City Home Team Name  \
# 60  Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro           Spain
# 61                           Durival de Brito        Curitiba          Sweden
# 62                              Independencia  Belo Horizonte             USA
# 63  Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro          Brazil
# ...

# %%
dt[:60]  # It is used to print the first 59 th rows starting from 0 index.
# Out:
#       Year              Datetime                  Stage  \
# 0   1930.0  13 Jul 1930 - 15:00                 Group 1
# 1   1930.0  13 Jul 1930 - 15:00                 Group 4
# 2   1930.0  14 Jul 1930 - 12:45                 Group 2
# 3   1930.0  14 Jul 1930 - 14:50                 Group 3
# 4   1930.0  15 Jul 1930 - 16:00                 Group 1
# 5   1930.0  16 Jul 1930 - 14:45                 Group 1
# 6   1930.0  17 Jul 1930 - 12:45                 Group 2
# 7   1930.0  17 Jul 1930 - 14:45                 Group 4
# 8   1930.0  18 Jul 1930 - 14:30                 Group 3
# 9   1930.0  19 Jul 1930 - 12:50                 Group 1
# 10  1930.0  19 Jul 1930 - 15:00                 Group 1
# 11  1930.0  20 Jul 1930 - 13:00                 Group 2
# 12  1930.0  20 Jul 1930 - 15:00                 Group 4
# 13  1930.0  21 Jul 1930 - 14:50                 Group 3
# 14  1930.0  22 Jul 1930 - 14:45                 Group 1
# 15  1930.0  26 Jul 1930 - 14:45             Semi-finals
# ...

# %%
dt[700:]  # It print the data starting from 700 to the end of the dataset.
# Out:
#        Year              Datetime                     Stage  \
# 700  2006.0  30 Jun 2006 - 17:00             Quarter-finals
# 701  2006.0  30 Jun 2006 - 21:00             Quarter-finals
# 702  2006.0  01 Jul 2006 - 17:00             Quarter-finals
# 703  2006.0  01 Jul 2006 - 21:00             Quarter-finals
# 704  2006.0  04 Jul 2006 - 21:00                Semi-finals
# ..      ...                   ...                       ...
# 847  2014.0  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014.0  08 Jul 2014 - 17:00                Semi-finals
# 849  2014.0  09 Jul 2014 - 17:00                Semi-finals
# 850  2014.0  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014.0  13 Jul 2014 - 16:00                      Final
#
#                                    Stadium             City Home Team Name  \
# 700                         Olympiastadion          Berlin         Germany
# 701        FIFA World Cup Stadium, Hamburg         Hamburg           Italy
# ...

# %%
dt.describe() #Returns descriptive statistics about the data like minimum, maximum,standard deviation,count,mean
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# ...

# %%
dt["Stadium"].describe() #Returns descriptive statistics about the stadium attribute or column
# Out:
# count                852
# unique               181
# top       Estadio Azteca
# freq                  19
# Name: Stadium, dtype: object

# %%
dt["Attendance"].describe() #Returns descriptive statistics about the Attendence attribute or column
# Out:
# count       850.000000
# mean      45164.800000
# std       23485.249247
# min        2000.000000
# 25%       30000.000000
# 50%       41579.500000
# 75%       61374.500000
# max      173850.000000
# Name: Attendance, dtype: float64

# %%
dt.info() # this method is used to generate the summary of the DataFrame,this will include info about columns with their names ,their datatypes ,and missing values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    float64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    float64
#  7   Away Team Goals       852 non-null    float64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    float64
#  12  Half-time Away Goals  852 non-null    float64
#  13  Referee               852 non-null    object
# ...

# %%
dt.columns  # It represent the column name by indexing.
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %%
dt.columns.values  # It is used to find the column name by in an array format.
# Out:
# array(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype=object)

# %%
dt.sort_values(by='City').head()  # This is used to sort the value.
# Out:
#        Year              Datetime                  Stage          Stadium  \
# 336  1982.0  23 Jun 1982 - 21:00                 Group 3  Jose Rico Perez
# 358  1982.0  10 Jul 1982 - 20:00   Match for third place  Jose Rico Perez
# 321  1982.0  18 Jun 1982 - 21:00                 Group 3  Jose Rico Perez
# 46   1938.0  12 Jun 1938 - 17:00          Quarter-finals      Fort Carree
# 152  1962.0  06 Jun 1962 - 15:00                 Group 1  Carlos Dittborn
#
#           City Home Team Name  Home Team Goals  Away Team Goals  \
# 336  Alicante       Argentina              2.0              0.0
# 358  Alicante          Poland              3.0              2.0
# 321  Alicante       Argentina              4.0              1.0
# 46    Antibes          Sweden              8.0              0.0
# 152     Arica    Soviet Union              2.0              1.0
#
#     Away Team Name Win conditions  Attendance  Half-time Home Goals  \
# ...

# %%
dt.nunique()
# Out:
# Year                     20
# Datetime                601
# Stage                    23
# Stadium                 181
# City                    151
# Home Team Name           78
# Home Team Goals          11
# Away Team Goals           7
# Away Team Name           83
# Win conditions           43
# Attendance              622
# Half-time Home Goals      7
# Half-time Away Goals      6
# Referee                 366
# Assistant 1             387
# Assistant 2             408
# RoundID                 101
# MatchID                 835
# Home Team Initials       77
# Away Team Initials       82
# dtype: int64

# %%
print(dt.shape) #It returns a tuple representing the dimensionalityof the Pandas DataFrame
# Out:
# (4572, 20)

# %%
dt.dtypes #this methods returns a series with the data type of each column
# Out:
# Year                    float64
# Datetime                 object
# Stage                    object
# Stadium                  object
# City                     object
# Home Team Name           object
# Home Team Goals         float64
# Away Team Goals         float64
# Away Team Name           object
# Win conditions           object
# Attendance              float64
# Half-time Home Goals    float64
# Half-time Away Goals    float64
# Referee                  object
# Assistant 1              object
# Assistant 2              object
# RoundID                 float64
# MatchID                 float64
# Home Team Initials       object
# Away Team Initials       object
# dtype: object

# %%
dt.sample() #this method is used to generate a sample random row or column from the dataframe
# Out:
#       Year Datetime Stage Stadium City Home Team Name  Home Team Goals  \
# 2261   NaN      NaN   NaN     NaN  NaN            NaN              NaN
#
#       Away Team Goals Away Team Name Win conditions  Attendance  \
# 2261              NaN            NaN            NaN         NaN
#
#       Half-time Home Goals  Half-time Away Goals Referee Assistant 1  \
# 2261                   NaN                   NaN     NaN         NaN
#
#      Assistant 2  RoundID  MatchID Home Team Initials Away Team Initials
# 2261         NaN      NaN      NaN                NaN                NaN

# %%
dt.size  #This methods returns the number of rows in the series .Otherwise returns the number of rows times the number of columns in the dataframe
# Out:
# 91440

# %%
dt.ndim #this function returns 1 if series and 2 if Dataframe
# Out:
# 2

# %%
dt['Attendance'].max()  # It is used to find the maximum value.
# Out:
# 173850.0

# %%
dt['Attendance'].min()  # It is used to find the minimum value of the dataset.
# Out:
# 2000.0

# %%
dt['Attendance'].mean()  # It is used to find the average value of the data.
# Out:
# 45164.8

# %%
dt['Attendance'].median()  # It is used to find the median value of the dataset.
# Out:
# 41579.5

# %%
dt['Attendance'].mode()[0]  # It is used to find the mode value of the dataset.
# Out:
# 43000.0

# %%
dt=pd.DataFrame(dt)  # This is used to print the data in a frame order.
dt.describe()
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   850.000000       850.000000       850.000000     850.000000
# mean   1985.021176         1.810588         1.022353   45164.800000
# std      22.431301         1.612125         1.088853   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            850.000000            850.000000  8.500000e+02  8.500000e+02
# mean               0.710588              0.429412  1.068626e+07  6.078489e+07
# std                0.937885              0.691752  2.732359e+07  1.105805e+08
# ...

# %%
dt.isnull().sum()  # It check the total null value in the dataset.
# Out:
# Year                    0
# Datetime                0
# Stage                   0
# Stadium                 0
# City                    0
# Home Team Name          0
# Home Team Goals         0
# Away Team Goals         0
# Away Team Name          0
# Win conditions          0
# Attendance              0
# Half-time Home Goals    0
# Half-time Away Goals    0
# Referee                 0
# Assistant 1             0
# Assistant 2             0
# RoundID                 0
# MatchID                 0
# Home Team Initials      0
# Away Team Initials      0
# dtype: int64

# %%
dt.dropna(inplace=True)  # By using this we can clean the missing value.
dt
# Out:
#        Year              Datetime                     Stage  \
# 0    1930.0  13 Jul 1930 - 15:00                    Group 1
# 1    1930.0  13 Jul 1930 - 15:00                    Group 4
# 2    1930.0  14 Jul 1930 - 12:45                    Group 2
# 3    1930.0  14 Jul 1930 - 14:50                    Group 3
# 4    1930.0  15 Jul 1930 - 16:00                    Group 1
# ..      ...                   ...                       ...
# 847  2014.0  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014.0  08 Jul 2014 - 17:00                Semi-finals
# 849  2014.0  09 Jul 2014 - 17:00                Semi-finals
# 850  2014.0  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014.0  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France              4.0
# 1         Parque Central      Montevideo             USA              3.0
# ...

# %%
x=dt['Attendance'].mean()
dt['Attendance'].fillna(x,inplace=True)  # By using this we can replace the null value.
dt
# Out:
#        Year              Datetime                     Stage  \
# 0    1930.0  13 Jul 1930 - 15:00                    Group 1
# 1    1930.0  13 Jul 1930 - 15:00                    Group 4
# 2    1930.0  14 Jul 1930 - 12:45                    Group 2
# 3    1930.0  14 Jul 1930 - 14:50                    Group 3
# 4    1930.0  15 Jul 1930 - 16:00                    Group 1
# ..      ...                   ...                       ...
# 847  2014.0  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014.0  08 Jul 2014 - 17:00                Semi-finals
# 849  2014.0  09 Jul 2014 - 17:00                Semi-finals
# 850  2014.0  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014.0  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France              4.0
# 1         Parque Central      Montevideo             USA              3.0
# ...

# %%
n=dt['Home Team Goals']
plt.plot(n,color='green',label='Home Team Goals')
plt.legend()
plt.show()

# %%
sns.displot(x='Year',data=dt)

# %%
sns.boxplot(dt['Away Team Goals'])  # This will show the data in a box way.
# Out:
# <Axes: ylabel='Away Team Goals'>

# %%
sns.scatterplot(x='Year',y='Home Team Goals',data=dt,hue='Away Team Goals')
# Out:
# <Axes: xlabel='Year', ylabel='Home Team Goals'>

# %%
sns.jointplot(data=dt, x="Away Team Goals", y="Attendance", hue="Home Team Goals")  # This will join the various columns and display the plots.

# %%
sns.pairplot(dt,hue='Year')  # This function is used to represent the plot in seperate way.

# %%
sns.barplot(x='Home Team Goals',y='RoundID',data=dt)  # This will represent the data in a bar graph.
# Out:
# <Axes: xlabel='Home Team Goals', ylabel='RoundID'>

# %%
corr=dt[['Year','Home Team Goals']].corr()
sns.heatmap(corr)  # This function shows the relation between the data.
# Out:
# <Axes: >

# %%
sns.histplot(data=dt,x='Year')
# Out:
# <Axes: xlabel='Year', ylabel='Count'>
